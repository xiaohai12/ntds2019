# %% [markdown]
# # [NTDS'19] assignment 2: learning with graphs
# [ntds'19]: https://github.com/mdeff/ntds_2019
#
# [Clément Vignac](https://people.epfl.ch/clement.vignac), [EPFL LTS4](https://lts4.epfl.ch) and
# [Guillermo Ortiz Jiménez](https://gortizji.github.io), [EPFL LTS4](https://lts4.epfl.ch).

# %% [markdown]
# ## Students
#
# * Team: `33`
# * Students: `<Yuxuan Long`> (for the indivudual submission) or `<the name of all students in the team>` (for the team submission)

# %% [markdown]
# ## Rules
#
# Grading:
# * The first deadline is for individual submissions. The second deadline is for the team submission.
# * All team members will receive the same grade based on the team solution submitted on the second deadline.
# * As a fallback, a team can ask for individual grading. In that case, solutions submitted on the first deadline are graded.
# * Collaboration between team members is encouraged. No collaboration between teams is allowed.
#
# Submission:
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart Kernel and Run All Cells" in Jupyter.

# %% [markdown]
# ## Objective
#
# In this assignment you will experiment with the main concepts of spectral graph theory, as well as familizarize yourself with the main data science techniques for network data.
#
# The assignment is made of three parts:
# 1. [Spectral Graph Theory](#sgt)
# 1. [Regularization on graphs with Graph Signal Processing](#gsp)
# 1. [Machine Learning on Graphs](#ml)

# %% [markdown]
# <a id='sgt'></a>
# ## Part I: Spectral Graph Theory
# ### Eigenvectors and eigenvalues
#
# We will start by reviewing some of the main concepts in spectral graph theory and see some of its applications to dimensionality reduction and data clustering. To illustrate the main concepts we will use the standard two moon dataset.

# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import scipy
np.seterr(divide='ignore', invalid='ignore')

# %matplotlib inline


# !pip install pygsp

# %%
from pygsp.graphs import TwoMoons

G = TwoMoons(moontype='synthesized', N=2000)
X = G.coords
Y = G.labels.astype(int)

plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.show()

# %% [markdown]
# #### Question 1: Graph construction
# Build a similarity graph using the euclidean distance between data points.
# **Note:** Use an RBF kernel to set the edge weights $w_{ij}=\exp(-||x_i- x_j||_2^2 / ~ 2 \sigma^2)$ of your adjacency and threshold the ones with the smallest magnitude.

# %%
def epsilon_similarity_graph(X: np.ndarray, sigma=None, epsilon=0):
    """ X (n x d): coordinates of the n data points in R^d.
        sigma (float): width of the kernel
        epsilon (float): threshold
        Return:
        adjacency (n x n ndarray): adjacency matrix of the graph.
    """
    # Your code here
    W = np.array([np.sum((X[i] - X)**2, axis = 1) for i in range(X.shape[0])])
    typical_dist = np.mean(np.sqrt(W))
    # print(np.mean(W))
    c = 0.35
    if sigma == None:
        sigma = typical_dist * c
    
    mask = W >= epsilon
    
    adjacency = np.exp(- W / 2.0 / (sigma ** 2))
    adjacency[mask] = 0.0
    adjacency -= np.diag(np.diag(adjacency))
    return adjacency

# %%
adjacency = epsilon_similarity_graph(X, sigma=None, epsilon=1.0)
plt.spy(adjacency)
plt.show()

# %% [markdown]
# How do you choose `sigma`?

# %% [markdown]
# *Your answer here:*
# We fix epsilon to 0 when tuning the sigma. Then we define the the typical distance $d$ as **mean Euclidean distance**. Finally an appropriate value of $c$ is chosen such that $sigma = c*d$, where $c = 0.35$ works best in our case.

# %% [markdown]
# How do you choose the threshold `epsilon`?

# %% [markdown]
# *Your answer here:*
# (Note that the epsilon is defined **differently** from the lecture and the idea of thresholding on Euclidean distances to connect edges is from the paper [Laplacian eigenmap](https://www2.imm.dtu.dk/projects/manifold/Papers/Laplacian.pdf), i.e. we connect the vertices whose Euclidean distances are smaller than epsilon. )
# Given the best sigma, we tune the epsilon to control the level of sparsity. We increase epsilon from very small value (e.g. 0.01) until we find that the graph is connected with a reasonable sparsity,

# %% [markdown]
# #### Question 2: Laplacian
# Build the combinatorial and normalized graph laplacians for this dataset.

# %%
def compute_laplacian(adjacency: np.ndarray, normalize: bool):
    """ Return:
        L (n x n ndarray): combinatorial or symmetric normalized Laplacian.
    """
    # Your code here
    d = np.sum(adjacency, axis = 1)
    d_sqrt = np.sqrt(d)  
    D = np.diag(1 / d_sqrt)
    if normalize:
        L = np.eye(adjacency.shape[0]) - (adjacency.T / d_sqrt).T / d_sqrt
        # L = np.dot(np.dot(D, np.diag(d) - adjacency), D)
    else:
        L = np.diag(d) - adjacency
    return L

# %%
laplacian_comb = compute_laplacian(adjacency, normalize=False)
laplacian_norm = compute_laplacian(adjacency, normalize=True)

# %% [markdown]
# #### Question 3: Eigendecomposition
#
# For both Laplacian matrices, compute the eigendecomposition $L = U^\top \Lambda U$, where the columns $u_k \in \mathbb{R}^N$ of $U = [u_1, \dots, u_N] \in \mathbb{R}^{N \times N}$ are the eigenvectors and the diagonal elements $\lambda_k = \Lambda_{kk}$ are the corresponding eigenvalues. Make sure that the eigenvalues are ordered, i.e., $\lambda_1 \leq \lambda_2 \leq \dots \leq \lambda_N$.
#
# Justify your choice of a solver for the eigendecomposition.

# %% [markdown]
# *Your answer here:*
# We notice that the Laplacian is always real symmetric and sparse, so here we use a specific solver for eigen-decomposition of symmetric matrix, which saves computing time.

# %%
def spectral_decomposition(laplacian: np.ndarray):
    """ Return:
        lamb (np.array): eigenvalues of the Laplacian
        U (np.ndarray): corresponding eigenvectors.
    """

    # lamb, U = scipy.linalg.eigh(laplacian, eigvals = (0, k - 1))
    
    # Your code here
    # lamb, U = np.linalg.eig(laplacian)
    lamb, U = np.linalg.eigh(laplacian)
    
    return lamb, U

# %%
lamb_comb, U_comb = spectral_decomposition(laplacian_comb)
lamb_norm, U_norm = spectral_decomposition(laplacian_norm)

# %% [markdown]
# #### Question 4: Interpretation
# We plot the sorted eigenvalues as a function of their index:

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(lamb_comb)
plt.xlabel('Index')
plt.ylabel('Eigenvalue')
plt.title('Eigenvalues $L_{comb}$')
plt.subplot(122)
plt.plot(lamb_norm)
plt.xlabel('Index')
plt.ylabel('Eigenvalue')
plt.title('Eigenvalues $L_{norm}$')
plt.show()

# %% [markdown]
# What is the lowest eigenvalue $\lambda_0$ and the corresponding eigenvector $u_0$? Answer for both Laplacian matrices.

# %% [markdown]
# *Your answer here:*
# For both Laplacian matrix, the lowest eigenvalue $\lambda_0$ is zero.
# For the combinatorial Laplacian, $u_0$ is just a vector of constant c, i.e.  $(u_0)_i = c$.
# For the normalized Laplacian, there also exsits one constant c such that $u_0 = c * diag(D^{1/2})$, where $D$ is degree matrix.
# Note that c is just a non-zero scaling factor in both cases.

# %% [markdown]
# When filtering a signal or computing polynomials, which Laplacian provides the best numerical stability? Justify your answer.

# %% [markdown]
# *Your answer here:*
#
# The eigenvalues of $L_{norm}$ are smaller and do not have much variation (i.e. most eigenvalues are around 1). Therefore, the normalized Laplacian provides the best numerical stability. For example, large eigenvalues may give rise to overflow when computing polynomials.
#
# <!--so most information are concentrated on small eigenvalues. -->

# %%
## ??

# %% [markdown]
# #### Question 5: Connected components
# The eigendecomposition provides an easy way to compute the number of connected components in the graph. Fill the following function:

# %%
def compute_number_connected_components(lamb: np.array, threshold: float):
    """ lamb: array of eigenvalues of a Laplacian
        Return:
        n_components (int): number of connected components.
    """
    # Your code here
    return np.sum(abs(lamb) <= threshold)

# %% [markdown]
# Tune the parameters $\epsilon$ and $\sigma$ of the similarity graph so that the graph is connected. Otherwise, clustering would be too simple!

# %%
print(compute_number_connected_components(lamb_norm, threshold=1e-15))
# Out:
# 1

# %%
##??

# %% [markdown]
# ### Spectral clustering
#
# Let us now see one application of spectral graph theory to clustering the two moon dataset.
#
# #### Question 6: Baseline
#
# As a baseline, let us first see how the simplest clustering algorithm, K-means, performs on this dataset. Use K-means to assign a cluster to each point.

# %%
from sklearn.cluster import KMeans

# Your code here
kmeans = KMeans(n_clusters=2).fit(X)
y_pred = kmeans.labels_ # Vector with cluster assignments
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %% [markdown]
# K-means cannot find a good solution to this problem. Why?

# %% [markdown]
# *Your answer here: *
# The optimal boundary presented in this dataset is **nonlinear**. However, K-means works best for **linearly seperable** data points.

# %% [markdown]
# #### Question 7: Spectral clustering
#
# As opposed to naive K-means, spectral clustering doesn't operate on the input space but on the eigenspace of the graph that represents the data. Implement spectral clustering. You can use
# [this tutorial](http://lasa.epfl.ch/teaching/lectures/ML_Phd/Notes/tutoSC.pdf).

# %%
class SpectralClustering():
    def __init__(self, n_classes: int, normalize: bool):
        self.n_classes = n_classes
        self.normalize = normalize
        self.laplacian = None
        self.e = None
        self.U = None
        self.clustering_method = KMeans(n_clusters = n_classes) # Your code here
        
    def fit_predict(self, adjacency):
        """ Your code should be correct both for the combinatorial
            and the symmetric normalized spectral clustering.
            Return:
            y_pred (np.ndarray): cluster assignments.
        """
        # Your code here
        self.laplacian = compute_laplacian(adjacency, self.normalize)
        lamb, U = spectral_decomposition(self.laplacian)
        u_k = U[:, 0:self.n_classes]
        if self.normalize:
            # normalize each row
            norm = np.sqrt(np.sum(u_k ** 2, axis = 1))
            u_k = (u_k.T / norm).T
        kmeans = self.clustering_method.fit(u_k)
        y_pred = kmeans.labels_
        return y_pred

# %%
print("Connected components:", compute_number_connected_components(lamb_norm, threshold=1e-12))
spectral_clustering = SpectralClustering(n_classes=2, normalize=True)
y_pred = spectral_clustering.fit_predict(adjacency)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()
# Out:
# Connected components: 1

# %% [markdown]
# #### Question 8: On your dataset
#
# Can you think of another 2D dataset in which k-means would badly perform, but spectral clustering would not?
# Construct it!
# For this question you can import any dataset of your choice, for example from `sklearn.datasets` or `pygsp.graphs`, but you can also get creative and define something of your own. First, create and plot the dataset.

# %%
# Your code here
theta = np.linspace(0, 2 * np.pi, 1000)
r1 = 3.0
r2 = 2.0
X1 = np.stack([np.cos(theta), np.sin(theta)]) * np.random.normal(r1, 0.1, size = 1000)
X2 = np.stack([np.cos(theta), np.sin(theta)]) * np.random.normal(r2, 0.1, size = 1000)
X = np.concatenate((X1, X2), axis = 1).T
Y = np.concatenate((np.ones(1000), np.zeros(1000))).astype(np.int)

plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.show()

# %% [markdown]
# Run K-means:

# %%
# Your code here
kmeans = KMeans(n_clusters=2).fit(X)
y_pred = kmeans.labels_ # Vector with cluster assignments
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %% [markdown]
# Create the similarity graph, and run spectral clustering with both the combinatorial and normalized Laplacian matrices:

# %%
# Your code here
adjacency = epsilon_similarity_graph(X, sigma=None, epsilon= 0.2)
# plt.spy(adjacency)
# plt.show()
f, axes = plt.subplots(1, 2, figsize=(14, 6))
spectral_clustering = SpectralClustering(n_classes=2, normalize=False)
y_pred = spectral_clustering.fit_predict(adjacency)
axes[0].scatter(X[:, 0], X[:, 1], c=y_pred)
axes[0].set_title('Spectral Clustering by Combinatorial Laplacian')

spectral_clustering = SpectralClustering(n_classes=2, normalize=True)
y_pred = spectral_clustering.fit_predict(adjacency)
axes[1].scatter(X[:, 0], X[:, 1], c=y_pred)
axes[1].set_title('Spectral Clustering by Normalized Laplacian')

laplacian = compute_laplacian(adjacency, normalize = True)
lamb, U = np.linalg.eigh(laplacian)
print("Connected components:", compute_number_connected_components(lamb, threshold=1e-12))
# Out:
# Connected components: 1

# %% [markdown]
# *Comment your results here:*
# The spectral clustering by both Laplacians works perfectly in our situation. On the other hand, K-means fails to distinguish these two circles since the decision boundary in our case is **nonlinear**.

# %% [markdown]
# ### Dimensionality Reduction with Laplacian Eigenmaps
#
# Most datasets are very high-dimensional, which means it can be very hard to understand their geometry. Fortunately, there exists multiple  techniques that can help us to reduce the dimensionality of the data, and allow us to visualize it.
#
# In this part of the assignment we will use MNIST to compare these techniques. Indeed, without dimensionality reduction it would be very difficult to answer questions like: are the different digits clustered together in different areas of space?
#
# But first, let's load our dataset:

# %%
from utils import load_mnist

X_mnist, y_mnist = load_mnist()
classes = np.unique(y_mnist)
print(X_mnist.shape)
# Out:
# (3000, 784)

# %%
# simple normalization to ease the graph construction
X_mnist /= 255.0

# %% [markdown]
# #### Question 9: Laplacian eigenmaps
#
# Most dimensionality reduction algorithms are constructed such that some property of the dataset remains invariant in the lower dimensional representation. Before implementing laplacian eigenmaps, can you say what property of the data does this algorithm preserve?

# %% [markdown]
# *Your answer here*
# The Laplacian eigenmaps will preserve the **local geometry** between the samples.

# %% [markdown]
# Implement a function that uses Laplacian eigenmaps to do dimensionality reduction.

# %%
def laplacian_eigenmaps(X:np.ndarray, dim: int, sigma: float, epsilon: float, normalize: bool):
    """ Return:
        coords (n x dim array): new coordinates for the data points."""
    # Your code here
    adjacency = epsilon_similarity_graph(X, sigma = sigma, epsilon = epsilon)
    laplacian = compute_laplacian(adjacency, normalize)
    lamb, U = spectral_decomposition(laplacian)

    u_k = U[:,1:(dim + 1)]
#     if normalize:
#         # normalize each row
#         norm = np.sqrt(np.sum(u_k ** 2, axis = 1))
#         u_k = (u_k.T / norm).T
    return u_k

# %% [markdown]
# Use this function to visualize MNIST in 2D. Feel free to play with the different parameters.

# %%
dim = 2
# Your code here
sigma = None
epsilon = 1000
normalize = True
adjacency = epsilon_similarity_graph(X_mnist, sigma = sigma, epsilon = epsilon)
plt.spy(adjacency)
plt.show()

# %%
u_k = laplacian_eigenmaps(X_mnist, dim, sigma, epsilon, normalize)
plt.scatter(u_k[:,0], u_k[:,1], c=y_mnist)
plt.show()

# %% [markdown]
# Visualize MNIST in 3D:

# %%
dim = 3
# Your code here
sigma = None
epsilon = 1000
normalize = True
adjacency = epsilon_similarity_graph(X_mnist, sigma = sigma, epsilon = epsilon)
plt.spy(adjacency)
plt.show()

# %%
u_k = laplacian_eigenmaps(X_mnist, dim, sigma, epsilon, normalize)

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(u_k[:, 0], u_k[:, 1], u_k[:, 2], c=y_mnist)
plt.show()

# %% [markdown]
# #### Question 10: Comparison with other methods
# We provide the visualization of MNIST with other methods:

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, Isomap

# This cell can take a few minutes to run
run_this_cell = True

if run_this_cell:
    # In 2d
    embeddings = [PCA(n_components=2, copy=True, whiten=True, tol=1e-5),
                  Isomap(n_components=2, n_neighbors=5),
                  TSNE(n_components=2)]

    for embedding in embeddings:
        X_embedded = embedding.fit_transform(X_mnist)
        fig = plt.figure()
        for i in classes:
            mask = y_mnist == i
            plt.scatter(X_embedded[mask, 0], X_embedded[mask, 1], label=i)
        plt.legend()
        plt.title('Embedding method: '+ type(embedding).__name__)
        plt.show()

    # In 3d
    embeddings = [PCA(n_components=3, copy=True, whiten=True, tol=1e-5),
                  Isomap(n_components=3, n_neighbors=5),
                  TSNE(n_components=3)]

    for embedding in embeddings:
        X_embedded = embedding.fit_transform(X_mnist)
        fig = plt.figure()
        ax = Axes3D(fig)
        for i in classes:
            mask = y_mnist == i
            ax.scatter(X_embedded[mask, 0], X_embedded[mask, 1], X_embedded[mask, 2], label=i)
        ax.legend()
        ax.title.set_text('Embedding method: '+ type(embedding).__name__)
        plt.show()

# %% [markdown]
# In a few words, what are the principles guiding the design of each method? Compare their results.

# %% [markdown]
# *Your answer here:*
#
# Principles:
# PCA aims to maximize the **variance** of the transformed data points.
# Isomap embeds the data in the way that **geodesic distance** is preserved.
# T-SNE aims to preserve the **similarity** (i.e. conditional probability) between data points in lower dimension, as to enable ease of separation between clusters.
#
# Results comparision:
# For the results, it can be hard to visually distinguish the clusters produced by PCA.
# Isomap produces better result than PCA as seen from the 3D plot.
# T-SNE shows the **best** result. Even if T-SNE is plotted in 2D space, we can still visually separate the clusters. So, T-SNE tends to solve crowding problem, whereas the other methods cannot.

# %% [markdown]
# <a id='gsp'></a>
# ## Part II: Regularization on graphs with Graph Signal Processing
#
# In this part of the assignment we are going to familiarize ourselves with the main concepts in Graph Signal Processing and regularization on graphs in general. From now on, you can only use the following libraries as well as the functions that you implemented in the previous parts.

# %%
import pandas as pd
import numpy as np
from pygsp.graphs import Bunny

# %% [markdown]
# In this exercise we will use a nearest-neighbor graph constructed from the Stanford Bunny point cloud included in the PyGSP library.

# %%
G = Bunny()
adjacency = np.asarray(G.W.todense())
n_nodes = adjacency.shape[0]

# %% [markdown]
# We will use the following function to plot our signals on this graph.

# %%
def plot_bunny(x=None, title='', vlim=[-0.03, 0.03]):
    fig = plt.gcf()
    ax = plt.gca()
    if not isinstance(ax, Axes3D):
        ax = plt.subplot(111, projection='3d')
    if x is not None:
        x = np.squeeze(x)

    p = ax.scatter(G.coords[:,0], G.coords[:,1], G.coords[:,2], c=x, marker='o',
                   s=5, cmap='RdBu_r', vmin=vlim[0], vmax=vlim[1])
    ax.view_init(elev=-90, azim=90)
    ax.dist = 7
    ax.set_axis_off()
    ax.set_title(title)
    if x is not None:
        fig.colorbar(p)

# %%
plt.subplot(111, projection='3d')
plot_bunny()

# %% [markdown]
# #### Question 11: Graph frequencies
#
# Let us start by constructing the normalized graph laplacians from the adjacency matrix and find its spectral decomposition.

# %%
laplacian = compute_laplacian(adjacency, normalize=True)
lam, U = spectral_decomposition(laplacian)

# %% [markdown]
# Plot the eigenvalues.

# %%
plt.figure(figsize=(6, 5))
plt.plot(lam)
plt.title('Eigenvalues $L_{norm}$')
plt.show()

# %% [markdown]
# To make things more clear we will plot some of its eigenvectors (0, 1, 3, 10, 100) as signals on the bunny graph.

# %%
plt.figure(figsize=(18, 9))
plt.subplot(231, projection='3d')
plot_bunny(x=U[:,0], title='Eigenvector #0')
plt.subplot(232, projection='3d')
plot_bunny(x=U[:,1], title='Eigenvector #1')
plt.subplot(233, projection='3d')
plot_bunny(x=U[:,2], title='Eigenvector #2')

plt.subplot(234, projection='3d')
plot_bunny(x=U[:,3], title='Eigenvector #3')
plt.subplot(235, projection='3d')
plot_bunny(x=U[:,10], title='Eigenvector #10')
plt.subplot(236, projection='3d')
plot_bunny(x=U[:,100], title='Eigenvector #100')

# %% [markdown]
# What can you say in terms of the variation (smoothness) of these signals? How can the smoothness of a signal be measured?

# %% [markdown]
# *Your answer here: *
# The signal associated with smaller eigenvalues tends to be smoother.
# The smoothness can be simply measured as $f^T L f$ given a graph signal $f$.

# %% [markdown]
# #### Question 12: Graph Fourier Transform
#
# Create a function to compute the Graph Fourier Transform (GFT) of a graph signal and its inverse.
# **Note**: You can assume that you have internal access to the eigendecomposition (`U` and `lam`) of the laplacian.

# %%
def GFT(signal: np.ndarray):
    # Your code here
    return np.dot(U.T, signal)

def iGFT(fourier_coefficients: np.ndarray):
    # Your code here
    return np.dot(U, fourier_coefficients)

# %% [markdown]
# Now, let's create a graph signal:

# %%
x = G.coords[:, 0] + G.coords[:, 1] + 3 * G.coords[:, 2]
x /= np.linalg.norm(x) 

noise = np.random.randn(n_nodes)
noise /= np.linalg.norm(noise) 

x_noisy = x + 0.3*noise

plot_bunny(x_noisy, vlim=[min(x_noisy), max(x_noisy)])
# Out:
# /Users/YuxuanLong/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# and plot its graph spectrum:

# %%
plt.figure(figsize=(10, 6))
plt.plot(lam, np.abs(GFT(x_noisy)), 'r.') 
plt.plot(lam, np.abs(GFT(x)), 'g-')
plt.xlabel('$\lambda$')
plt.ylabel('GFT')
plt.legend(['$x_{noisy}$', '$x$'])

# %% [markdown]
# #### Question 13: Graph filters
#
# We will try to extract the signal from the noise using graph filters. Let us start by creating three ideal graph filters.

# %%
ideal_lp = np.ones((n_nodes,))
ideal_bp = np.ones((n_nodes,))
ideal_hp = np.ones((n_nodes,))

ideal_lp[lam >= 0.1] = 0  # Low-pass filter with cut-off at lambda=0.1
ideal_bp[lam < 0.1] = 0  # Band-pass filter with cut-offs at lambda=0.1 and lambda=0.5
ideal_bp[lam > 0.5] = 0
ideal_hp[lam <= 1] = 0  # High-pass filter with cut-off at lambda=1

# %% [markdown]
# Additionally, create the ideal graph filter that implements the solution of Tikhonov regularization.

# %%
alpha = 0.99 / np.max(lam)

ideal_tk = 1.0 / (1.0 + alpha * lam) # Your code here

# %% [markdown]
# Let's plot the spectral responses:

# %%
plt.plot(lam, ideal_lp, '-', label='LP')
plt.plot(lam, ideal_bp, '-', label='BP')
plt.plot(lam, ideal_hp, '-', label='HP')
plt.plot(lam, ideal_tk, '-', label='Tikhonov')
plt.xlabel('$\lambda$')
plt.ylabel('Spectral response')
plt.legend(loc='lower right')

# %% [markdown]
# Create a function to filter a signal given an ideal graph filter

# %%
def ideal_graph_filter(x: np.ndarray, spectral_response: np.ndarray):
    """Return a filtered signal."""
    # Your code here
    conv_out = spectral_response * GFT(x)
    return iGFT(conv_out)

# %% [markdown]
# Let us visualize the results:

# %%
x_lp = ideal_graph_filter(x_noisy,ideal_lp)
x_bp = ideal_graph_filter(x_noisy,ideal_bp)
x_hp = ideal_graph_filter(x_noisy,ideal_hp)
x_tk = ideal_graph_filter(x_noisy,ideal_tk)

plt.figure(figsize=(18, 9))
plt.subplot(231, projection='3d')
plot_bunny(x=x, title='signal (true)', vlim=[min(x), max(x)])
plt.subplot(232, projection='3d')
plot_bunny(x=x_noisy, title='signal (noisy)', vlim=[min(x), max(x)])
plt.subplot(233, projection='3d')
plot_bunny(x=x_lp, title='Low-pass', vlim=[min(x_lp), max(x_lp)])
plt.subplot(234, projection='3d')
plot_bunny(x=x_bp, title='Band-pass', vlim=[min(x_bp), max(x_bp)])
plt.subplot(235, projection='3d')
plot_bunny(x=x_hp, title='High-pass', vlim=[min(x_hp), max(x_hp)])
plt.subplot(236, projection='3d')
plot_bunny(x=x_tk, title='Tikhonov denoised signal', vlim=[min(x_tk), max(x_tk)])

# %% [markdown]
# How would you link to the observations you made before about the spectral decomposition of the laplacian?
# Also, judging from the results, what type of model prior do you think Tikhonov regularization enforces?

# %% [markdown]
# *Your answer here*

# %% [markdown]
# As seen in the spectral decomposition, the noisy signal and the original signal tallies with each other at low frequencies ($\lambda &lt;= 0.1$) and mainly differs at higher frequencies. Here, the low-pass filtered result and the Tikhonov denoised result yield good results as they can filter out the noise that are of higher frequency.

# %% [markdown]
# Tikhonov regularization yield similar result as a low-pass filter, as Tikhonov regularization enforces a smoothness prior and penalizes solution that change rapidly.

# %% [markdown]
# #### Question 14: Polynomial graph filters
#
# We have seen how we can use the GFT to define different filters that enhance or reduce certain frequency bands. However, to do so, we require an explicit eigendecomposition of the graph laplacian, which has a cost $O(n^3)$. For very large graphs this is very intense computationally. We will now see how we can obtain similar results by filtering the signals directly without resorting to an eigendecomposition.
#
# The key idea is to use a polynomial of the graph laplacian to define a graph filter, i.e., $g(L)x=\sum_{k=1}^K \alpha_k L^k x$, and use the fact that the powers of a diagonalizable matrix can be written in terms of powers of its eigenvalues. This is
# $$
# L^k=(U\Lambda U^T)^k=U\Lambda^k U^T = U\begin{bmatrix}
# (\lambda_0)^k &\dots & 0\\
# \vdots & \ddots & \vdots\\
# 0 & \dots & (\lambda_N)^k
# \end{bmatrix} U^T.
# $$
#
# This means that a polynomial of the graph laplacian acts independently on each eigenvalue of the graph, and has a frequency spectrum of
# $$g(\lambda)=\sum_{k=1}^K \alpha_k \lambda^k.$$
# Hence,
# $$g(L)x=\sum_{k=1}^K \alpha_k L^k x=\sum_{k=1}^K \alpha_k U\Lambda^k U^T x=U \left(\sum_{k=1}^K \alpha_k\Lambda^k \right)U^T x=\operatorname{iGFT}\left(g(\Lambda)\operatorname{GFT}(x)\right).$$
#
# With these ingredients, we have reduced the design of graph filters in the vertex domain to a regression task that approximates a given spectral response by a polynomial. There are multiple ways to do this, but in this assignment we will implement a very simple strategy based on [least-squares regression](https://en.wikipedia.org/wiki/Polynomial_regression#Matrix_form_and_calculation_of_estimates).

# %% [markdown]
# Implement a function to find the coefficients of a polynomial that approximates a given ideal filter.
# **Hint:** `np.vander` and `np.linalg.lstsq`.

# %%
def fit_polynomial(lam: np.ndarray, order: int, spectral_response: np.ndarray):
    """ Return an array of polynomial coefficients of length 'order'."""  # ak
    # Your code here
    X_vander = np.vander(lam,order,increasing=True)
    poly_coeff = np.linalg.lstsq(X_vander, spectral_response, rcond=None)[0]
    return poly_coeff

# %% [markdown]
# Implement a function to compute the frequency response of that filter.

# %%
def polynomial_graph_filter_response(coeff: np.array, lam: np.ndarray):
    """ Return an array of the same shape as lam.
        response[i] is the spectral response at frequency lam[i]. """
    # Your code here
    X_vander = np.vander(lam,coeff.shape[0],increasing=True) 
    return np.dot(X_vander,coeff)

# %% [markdown]
# Let us fit the Tikhonov ideal filter with several polynomials of different order.

# %%
plt.plot(lam, ideal_tk)
orders = [1, 2, 3, 5, 10, 20]
for order in orders:    
    coeff_tk = fit_polynomial(lam, order, ideal_tk)
    plt.plot(lam, polynomial_graph_filter_response(coeff_tk, lam))
plt.xlabel('$\lambda$')
plt.ylabel('Spectral response')
plt.legend(['tk']+orders)

# %%
laplacian.shape
# Out:
# (2503, 2503)

# %% [markdown]
# So far, we have only defined a way to compute the coefficients of our laplacian polynomial. Let us now compute our graph filter.

# %%
def polynomial_graph_filter(coeff: np.array, laplacian: np.ndarray):
    """ Return the laplacian polynomial with coefficients 'coeff'. """
    # Your code here
    coeffs = np.zeros(laplacian.shape)
    for i in range(coeff.shape[0]):
        coeffs += coeff[i] * np.linalg.matrix_power(laplacian, i)
    return coeffs

# %% [markdown]
# Based on the previous plot, choose a filter order that achieves (in your opinion) a good tradeoff in terms of computational complexity and response accuracy.

# %%
order = 5 # Your code here
coeff_tk = fit_polynomial(lam, order, ideal_tk)
g_tk = polynomial_graph_filter(coeff_tk, laplacian)

# %% [markdown]
# #### Question 15: ARMA filter
#
# As you have seen in class, polynomial graph filters are only one of the ways in which you can approximate ideal graph filters.
# In this sense, ARMA filters are a natural way to implement Tikhonov denoising on graphs.
# Let us recall the general solution of the Tikhonov regularized denoising problem
#
# $$y=(I+\alpha L)^{-1}x. $$
#
# With a little bit of algebra manipulation we can rewrite this expression as
# $$
#     y = -\alpha L y + x,
# $$
# from which we can derive the iterative algorithm
# $$
#     y_k = -\alpha L y_{k-1} + x\qquad k=1,2,\dots
# $$
# which is guaranteed to converge as long as $\alpha \lambda_{max} < 1$.

# %% [markdown]
# Implement the ARMA version of Tikhonov regularization.

# %%
def arma_tikhonov(x: np.ndarray, laplacian: np.ndarray, alpha: float, max_iter=50):
    """ Return an array of the same shape as x."""
    # Your code here
    y = x
    for i in range(max_iter):
        y = (-alpha*laplacian) @ y + x 
    return y

# %% [markdown]
# Filter the previous noisy graph signal with the polynomial and ARMA approximations of the ideal Tikhonov filter.

# %%
x_tk_polynomial = g_tk @ x_noisy # Your code here
x_tk_arma = arma_tikhonov(x_noisy, laplacian, alpha)

# %% [markdown]
# Let us compare with the previous version.

# %%
plt.figure(figsize=(18, 4))
plt.subplot(131, projection='3d')
plot_bunny(x_tk, title='Ideal filter', vlim=[min(x_tk), max(x_tk)])
plt.subplot(132, projection='3d')
plot_bunny(x_tk_polynomial, title='Polynomial filter', vlim=[min(x_tk), max(x_tk)])
plt.subplot(133, projection='3d')
plot_bunny(x_tk_arma, title='ARMA filter', vlim=[min(x_tk), max(x_tk)])

# %% [markdown]
# <a id='ml'></a>
# ## Part III: Machine Learning on Graphs
#
# So far, we have only played with toy examples. Let us see the use of these tools in practice! In particular, let us see how we can use some graph filters to construct features to feed a classifier. For this part of the assignment we will import some extra packages.

# %%
# !pip install dgl
import time

import networkx as nx
from sklearn.linear_model import LogisticRegression

import torch
import torch.nn as nn
import torch.nn.functional as F

import dgl.function as fn
from dgl import DGLGraph
from dgl.data.citation_graph import load_cora

np.random.seed(0)
torch.manual_seed(1)
# Out:
# Collecting dgl
#   Downloading https://files.pythonhosted.org/packages/ac/49/c885f03f481a72b175f8e65873086a5c2baa5c81cc39fa701e133dcf5b3d/dgl-0.4.1-cp36-cp36m-macosx_10_7_x86_64.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 1.2MB/s
# Requirement already satisfied: networkx>=2.1 in /Users/YuxuanLong/anaconda3/lib/python3.6/site-packages (from dgl) (2.1)
# Requirement already satisfied: numpy>=1.14.0 in /Users/YuxuanLong/anaconda3/lib/python3.6/site-packages (from dgl) (1.14.6)
# Requirement already satisfied: scipy>=1.1.0 in /Users/YuxuanLong/anaconda3/lib/python3.6/site-packages (from dgl) (1.1.0)
# Requirement already satisfied: decorator>=4.1.0 in /Users/YuxuanLong/anaconda3/lib/python3.6/site-packages (from networkx>=2.1->dgl) (4.3.0)
# Installing collected packages: dgl
# Successfully installed dgl-0.4.1

# %% [markdown]
# We will use the CORA dataset and the citation graph that we created in Assignment 1. However, to simplify the next tasks we will directly use the preprocessed version of this dataset contained within the Deep Graph Library (DGL).
#
# In this assignment, we will interpret CORA's features as multidimensional graph signals living on the citation graph.
# Our task is to design a classifier that uses these features and the geometry of the graph can identify the type of paper each node represents.
#
# The goal of this exercise is to do semi-supervised learning on graphs.
# We assume that we know to which scientific field a small subset of the papers belongs (the ones contained in `train_mask`).
# The goal is to predict to which field the other papers belong, using both the citation graph and the bag-of-word representation of each paper.

# %%
cora = load_cora()

features = torch.FloatTensor(cora.features)    # Feature vector for each paper
labels = torch.LongTensor(cora.labels)         # The field to which each paper belongs

train_mask = torch.BoolTensor(cora.train_mask) # Mask of nodes selected for training
val_mask = torch.BoolTensor(cora.val_mask)     # Mask of nodes selected for validation
test_mask = torch.BoolTensor(cora.test_mask)   # Mask of nodes selected for testing

in_feats = features.shape[1]
n_classes = cora.num_labels
n_edges = cora.graph.number_of_edges()

graph = cora.graph
adjacency = np.asarray(nx.to_numpy_matrix(graph))
n_nodes = adjacency.shape[0]
# Out:
# Downloading /Users/YuxuanLong/.dgl/cora.zip from https://s3.us-east-2.amazonaws.com/dgl.ai/dataset/cora_raw.zip...
# Extracting file to /Users/YuxuanLong/.dgl/cora
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-884a96e1f06f> in <module>()
#       4 labels = torch.LongTensor(cora.labels)         # The field to which each paper belongs
#       5
# ----> 6 train_mask = torch.BoolTensor(cora.train_mask) # Mask of nodes selected for training
#       7 val_mask = torch.BoolTensor(cora.val_mask)     # Mask of nodes selected for validation
#       8 test_mask = torch.BoolTensor(cora.test_mask)   # Mask of nodes selected for testing
#
# AttributeError: module 'torch' has no attribute 'BoolTensor'

# %% [markdown]
# For this exercise we will use the normalized laplacian.

# %%
laplacian = compute_laplacian(adjacency, normalize=True)
lam, U = spectral_decomposition(laplacian)
lam_max = np.max(lam)

# %% [markdown]
# #### Question 16: Logistic regression
#
# The simplest classification method consists in ignoring the citation graph and trying to classify the papers using only the features.
# In this case, the problem is viewed as a standard classification task.
# To train our classifier we will select a few nodes in our graph for training and fit a [logistic regression classifier](https://en.wikipedia.org/wiki/Logistic_regression) on them.
# To avoid overfitting to the test set when we do hyperparameter tuning, we will also select a validation set.
# And finally, we will test our classifier on the rest of the nodes.
# **Hint:** use `sklearn.linear_model.LogisticRegression`.

# %%
train_features = features[train_mask]
train_labels = labels[train_mask]
val_features = features[val_mask]
val_labels = labels[val_mask]
test_features = features[test_mask]
test_labels = labels[test_mask]

# %%
clf =LogisticRegression(C=60,penalty='l2',solver='sag').fit(train_features,train_labels)
clf.score(train_features,train_labels)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 1.0

# %%
# Fit a logistic regression model
# Your code here
penaltys = ['l1','l2']
C_group =  np.linspace(90,150, num=2)
score_train = []
score_val = []
for c in C_group:
    clf =LogisticRegression(C=c,penalty='l2',solver='sag',multi_class='multinomial').fit(train_features,train_labels)
    score_train.append(clf.score(train_features,train_labels))
    score_val.append(clf.score(val_features,val_labels))
    print('C is ',c)
    print('train accuracy is :' ,score_train[-1])
    print('validate accuracy is :' ,score_val[-1])
clf =LogisticRegression(C=100,penalty='l2',solver='lbfgs').fit(train_features,train_labels)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  90.0
# train accuracy is : 1.0
# validate accuracy is : 0.5766666666666667
# C is  150.0
# train accuracy is : 1.0
# validate accuracy is : 0.58
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
train_acc = clf.score(train_features,train_labels)# Your code here
val_acc =  # Your code here
test_acc =  # Your code here

print('Train accuracy {:.4f} | Validation accuracy {:.4f} | Test accuracy {:.4f}'.format(train_acc, val_acc, test_acc))

# %% [markdown]
# #### Question 17: Handcrafted graph filters
#
# That's not a bad start! Now, let's try to improve a bit the results by taking into account the graph structure using tools from GSP. For this purpose, we will design a handcrafted filter that will be used to denoise the signal, before feeding it to a logistic regression.
#
# However, before we start, what hypothesis can you make on the spectral properties of the denoised signal?

# %% [markdown]
# *Your answer here*

# %% [markdown]
# Based on this prior, design an ideal filter response that you believe could enhance important features of the graph.
#
# **Note:** you just need to design one graph filter that we will apply to all features. Don't design a different filter for each feature.
#
# **Note:** finding the right filter can be very challenging, don't worry if you can't find it. Just make sure you experiment with a few configurations and parameters.

# %%
ideal_filter = np.ones((n_nodes,))
ideal_filter[lam >= 0.85] = 0  # Store your spectral response here

# %%
plt.hist(lam)
# Out:
# (array([241., 217., 231., 233., 336., 411., 319., 336., 250., 134.]),
#  array([-3.21472859e-15,  2.00000000e-01,  4.00000000e-01,  6.00000000e-01,
#          8.00000000e-01,  1.00000000e+00,  1.20000000e+00,  1.40000000e+00,
#          1.60000000e+00,  1.80000000e+00,  2.00000000e+00]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Choose a filter order to approximate your filter using laplacian polynomials.

# %%
order = 10 # Your code here

coeff = fit_polynomial(lam, order, ideal_filter)
graph_filter = polynomial_graph_filter(coeff, laplacian)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-b73d4e7ed4e6> in <module>()
#       1 order = 10 # Your code here
#       2
# ----> 3 coeff = fit_polynomial(lam, order, ideal_filter)
#       4 graph_filter = polynomial_graph_filter(coeff, laplacian)
#
# NameError: name 'ideal_filter' is not defined

# %% [markdown]
# Let's plot the frequency response of your spectral template and its polynomial approximation.

# %%
plt.plot(lam, ideal_filter)
plt.plot(lam, polynomial_graph_filter_response(coeff, lam))
plt.legend(['Ideal', 'Polynomial'])
plt.xlabel('$\lambda$')
plt.ylabel('Spectral response')
# Out:
# Text(0, 0.5, 'Spectral response')

# %% [markdown]
# Now, let's create the new features.

# %%
filtered_features = graph_filter @ features.numpy()

train_features = filtered_features[train_mask,:]
train_labels = labels[train_mask]

val_features = filtered_features[val_mask,:]
val_labels = labels[val_mask]

test_features = filtered_features[test_mask,:]
test_labels = labels[test_mask]

# %% [markdown]
# Train another logistic regression classifier on the new features. Remember to play with the regularization parameters to achieve a well performing model.

# %%
# Your code here
C_group =  np.linspace(150,165, num=15)
score_train = []
score_val = []
for c in C_group:
    clf =LogisticRegression(C=c,penalty='l2',solver='sag',multi_class='multinomial').fit(train_features,train_labels)
    score_train.append(clf.score(train_features,train_labels))
    score_val.append(clf.score(val_features,val_labels))
    print('C is ',c)
    print('train accuracy is :' ,score_train[-1])
    print('validate accuracy is :' ,score_val[-1])
    
C = C_group[np.argmax(score_val)]
clf =LogisticRegression(C=C,penalty='l2',solver='sag',multi_class='multinomial').fit(train_features,train_labels)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  150.0
# train accuracy is : 0.9785714285714285
# validate accuracy is : 0.7266666666666667
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  151.07142857142858
# train accuracy is : 0.9785714285714285
# validate accuracy is : 0.7266666666666667
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  152.14285714285714
# train accuracy is : 0.9785714285714285
# validate accuracy is : 0.7266666666666667
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  153.21428571428572
# train accuracy is : 0.9785714285714285
# validate accuracy is : 0.7233333333333334
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  154.28571428571428
# train accuracy is : 0.9785714285714285
# validate accuracy is : 0.7266666666666667
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  155.35714285714286
# train accuracy is : 0.9785714285714285
# validate accuracy is : 0.73
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  156.42857142857142
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.73
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  157.5
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.73
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  158.57142857142858
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.73
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  159.64285714285714
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.73
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  160.71428571428572
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.73
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  161.78571428571428
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.73
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  162.85714285714286
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.7266666666666667
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  163.92857142857142
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.73
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  165.0
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.7266666666666667
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %% [markdown]
# Evaluate your model.

# %%
train_acc = clf.score(train_features,train_labels) # Your code here
val_acc =clf.score(val_features,val_labels)  # Your code here
test_acc = clf.score(test_features,test_labels)  # Your code here

print('Train accuracy {:.4f} | Validation accuracy {:.4f} | Test accuracy {:.4f}'.format(train_acc, val_acc, test_acc))
# Out:
# Train accuracy 0.9786 | Validation accuracy 0.7300 | Test accuracy 0.6430

# %% [markdown]
# #### Question 18: Graph convolutional networks
#
# By now, you will probably have seen that it is challenging to find the right combination of spectral response, filter parameters and regularization method. And in most cases, this is a painstaking job. Wouldn't it be great to automate these tasks?
#
# Fortunately, this is possible if we use the right tools! Specifically, we will see that Graph Convolutional Networks are a great framework to automatize the feature extraction method.
#
# In this exercise, we will follow the same classification pipeline as above, but instead of hand-crafting our filter we will let `PyTorch` find the coefficients for us using gradient descent.
#
# In this section, most of the code is already written. Try to understand it and to play with some parameters. It may be useful if you want to solve some learning task in your project.
#
# We start by constructing a `LaplacianPolynomial` model in `DGL`. It computes the function: $f(X) = \sum_{i=1}^{k} \alpha_i L^i X \theta$ where the trainable parameters are the coefficients $\alpha_i$ and the matrix $\theta$. This function can be interpreted as a filtering of $X$ by $\sum_{i=1}^{k} \alpha_i L^i$ followed by a linear layer.

# %%
class LaplacianPolynomial(nn.Module):
    def __init__(self,
                 in_feats: int,
                 out_feats: int,
                 k: int,
                 dropout_prob: float,
                 norm=True):
        super().__init__()
        self._in_feats = in_feats
        self._out_feats = out_feats
        self._k = k
        self._norm = norm
        # Contains the weights learned by the Laplacian polynomial
        self.pol_weights = nn.Parameter(torch.Tensor(self._k + 1))
        # Contains the weights learned by the logistic regression (without bias)
        self.logr_weights = nn.Parameter(torch.Tensor(in_feats, out_feats))
        self.dropout = nn.Dropout(p=dropout_prob)
        self.reset_parameters()

    def reset_parameters(self):
        """Reinitialize learnable parameters."""
        torch.manual_seed(0)
        torch.nn.init.xavier_uniform_(self.logr_weights, gain=0.01)
        torch.nn.init.normal_(self.pol_weights, mean=0.0, std=1e-3)

    def forward(self, graph, feat):
        r"""Compute graph convolution.

        Notes
        -----
        * Input shape: :math:`(N, *, \text{in_feats})` where * means any number of additional
          dimensions, :math:`N` is the number of nodes.
        * Output shape: :math:`(N, *, \text{out_feats})` where all but the last dimension are
          the same shape as the input.

        Parameters
        ----------
        graph (DGLGraph) : The graph.
        feat (torch.Tensor): The input feature

        Returns
        -------
        (torch.Tensor) The output feature
        """
        feat = self.dropout(feat)
        graph = graph.local_var()
        
        # D^(-1/2)
        norm = torch.pow(graph.in_degrees().float().clamp(min=1), -0.5)
        shp = norm.shape + (1,) * (feat.dim() - 1)
        norm = torch.reshape(norm, shp)

        # mult W first to reduce the feature size for aggregation.
        feat = torch.matmul(feat, self.logr_weights)

        result = self.pol_weights[0] * feat.clone()

        for i in range(1, self._k + 1):
            old_feat = feat.clone()
            if self._norm:
                feat = feat * norm
            graph.ndata['h'] = feat
            # Feat is not modified in place
            graph.update_all(fn.copy_src(src='h', out='m'),
                             fn.sum(msg='m', out='h'))
            if self._norm:
                graph.ndata['h'] = graph.ndata['h'] * norm

            feat = old_feat - graph.ndata['h']
            result += self.pol_weights[i] * feat

        return result

    def extra_repr(self):
        """Set the extra representation of the module,
        which will come into effect when printing the model.
        """
        summary = 'in={_in_feats}, out={_out_feats}'
        summary += ', normalization={_norm}'
        return summary.format(**self.__dict__)

# %% [markdown]
# Once we have are model ready we just need to create a function that performs one step of our training loop, and another one that evaluates our model.

# %%
def train(model, g, features, labels, loss_fcn, train_mask, optimizer):
    model.train()  # Activate dropout
    
    logits = model(g, features)
    loss = loss_fcn(logits[train_mask], labels[train_mask])

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    return loss

def evaluate(model, g, features, labels, mask):
    model.eval()  # Deactivate dropout
    with torch.no_grad():
        logits = model(g, features)[mask]  # only compute the evaluation set
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)

# %% [markdown]
# Choose the training parameters.

# %%
pol_order = 2
lr = 1
weight_decay = 5e-6
n_epochs = 265
p_dropout = 0.75

# %% [markdown]
# And train the classifier end to end.

# %%
graph = DGLGraph(cora.graph)

model = LaplacianPolynomial(in_feats, n_classes, pol_order, p_dropout)

loss_fcn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),#lr=2, momentum=0.9)
                             lr=lr,
                             weight_decay=weight_decay)
#optimizer = torch.optim.SGD(model.parameters(),lr=2, momentum=0.9)

dur = []
for epoch in range(n_epochs):
    if epoch >= 3:
        t0 = time.time()
    loss = train(model, graph, features, labels, loss_fcn, train_mask, optimizer)

    if epoch >= 3:
        dur.append(time.time() - t0)

    acc = evaluate(model, graph, features, labels, val_mask)
    print("Epoch {:05d} | Time(s) {:.4f} | Train Loss {:.4f} | Val Accuracy {:.4f}". format(
            epoch, np.mean(dur), loss.item(), acc))

print()
acc = evaluate(model, graph, features, labels, test_mask)
print("Test Accuracy {:.4f}".format(acc))
# Out:
# Epoch 00000 | Time(s) nan | Train Loss 1.9459 | Val Accuracy 0.1967
# Epoch 00001 | Time(s) nan | Train Loss 1.9657 | Val Accuracy 0.1733
# Epoch 00002 | Time(s) nan | Train Loss 1.9972 | Val Accuracy 0.2267
# Epoch 00003 | Time(s) 0.3018 | Train Loss 1.6155 | Val Accuracy 0.3333
# Epoch 00004 | Time(s) 0.3020 | Train Loss 1.2193 | Val Accuracy 0.3467
# Epoch 00005 | Time(s) 0.3333 | Train Loss 1.5592 | Val Accuracy 0.3633
# Epoch 00006 | Time(s) 0.3254 | Train Loss 0.9087 | Val Accuracy 0.3567
# Epoch 00007 | Time(s) 0.3409 | Train Loss 0.6822 | Val Accuracy 0.3400
# Epoch 00008 | Time(s) 0.3836 | Train Loss 1.0539 | Val Accuracy 0.3733
# Epoch 00009 | Time(s) 0.4141 | Train Loss 0.9919 | Val Accuracy 0.4300
# Epoch 00010 | Time(s) 0.4250 | Train Loss 0.7739 | Val Accuracy 0.4333
# Epoch 00011 | Time(s) 0.4340 | Train Loss 0.6111 | Val Accuracy 0.4400
# Epoch 00012 | Time(s) 0.4306 | Train Loss 0.5972 | Val Accuracy 0.4500
# Epoch 00013 | Time(s) 0.4370 | Train Loss 0.4952 | Val Accuracy 0.4800
# Epoch 00014 | Time(s) 0.4276 | Train Loss 0.4038 | Val Accuracy 0.4867
# Epoch 00015 | Time(s) 0.4384 | Train Loss 0.6724 | Val Accuracy 0.5000
# Epoch 00016 | Time(s) 0.4355 | Train Loss 0.4033 | Val Accuracy 0.5000
# Epoch 00017 | Time(s) 0.4332 | Train Loss 0.4669 | Val Accuracy 0.4967
# Epoch 00018 | Time(s) 0.4315 | Train Loss 0.3393 | Val Accuracy 0.5000
# Epoch 00019 | Time(s) 0.4295 | Train Loss 0.5050 | Val Accuracy 0.5200
# Epoch 00020 | Time(s) 0.4280 | Train Loss 0.3384 | Val Accuracy 0.5233
# Epoch 00021 | Time(s) 0.4217 | Train Loss 0.2940 | Val Accuracy 0.5233
# Epoch 00022 | Time(s) 0.4159 | Train Loss 0.4428 | Val Accuracy 0.5300
# Epoch 00023 | Time(s) 0.4059 | Train Loss 0.2765 | Val Accuracy 0.5467
# Epoch 00024 | Time(s) 0.4099 | Train Loss 0.4769 | Val Accuracy 0.5533
# Epoch 00025 | Time(s) 0.4094 | Train Loss 0.3108 | Val Accuracy 0.5500
# Epoch 00026 | Time(s) 0.4081 | Train Loss 0.1937 | Val Accuracy 0.5533
# Epoch 00027 | Time(s) 0.4032 | Train Loss 0.2592 | Val Accuracy 0.5633
# Epoch 00028 | Time(s) 0.4030 | Train Loss 0.2845 | Val Accuracy 0.5733
# Epoch 00029 | Time(s) 0.4029 | Train Loss 0.1846 | Val Accuracy 0.5933
# Epoch 00030 | Time(s) 0.3994 | Train Loss 0.2175 | Val Accuracy 0.5833
# Epoch 00031 | Time(s) 0.3993 | Train Loss 0.2791 | Val Accuracy 0.5833
# Epoch 00032 | Time(s) 0.3999 | Train Loss 0.1338 | Val Accuracy 0.5933
# Epoch 00033 | Time(s) 0.4000 | Train Loss 0.2791 | Val Accuracy 0.5967
# Epoch 00034 | Time(s) 0.3976 | Train Loss 0.1886 | Val Accuracy 0.6167
# Epoch 00035 | Time(s) 0.3977 | Train Loss 0.2017 | Val Accuracy 0.6233
# Epoch 00036 | Time(s) 0.4036 | Train Loss 0.2834 | Val Accuracy 0.6233
# Epoch 00037 | Time(s) 0.4175 | Train Loss 0.2769 | Val Accuracy 0.6233
# Epoch 00038 | Time(s) 0.4168 | Train Loss 0.1591 | Val Accuracy 0.6400
# Epoch 00039 | Time(s) 0.4242 | Train Loss 0.2489 | Val Accuracy 0.6567
# Epoch 00040 | Time(s) 0.4184 | Train Loss 0.2688 | Val Accuracy 0.6733
# Epoch 00041 | Time(s) 0.4180 | Train Loss 0.1706 | Val Accuracy 0.6833
# Epoch 00042 | Time(s) 0.4201 | Train Loss 0.1959 | Val Accuracy 0.6867
# Epoch 00043 | Time(s) 0.4195 | Train Loss 0.1853 | Val Accuracy 0.6800
# Epoch 00044 | Time(s) 0.4190 | Train Loss 0.0820 | Val Accuracy 0.6700
# Epoch 00045 | Time(s) 0.4191 | Train Loss 0.2423 | Val Accuracy 0.6733
# Epoch 00046 | Time(s) 0.4185 | Train Loss 0.2306 | Val Accuracy 0.6900
# Epoch 00047 | Time(s) 0.4181 | Train Loss 0.1131 | Val Accuracy 0.6867
# Epoch 00048 | Time(s) 0.4198 | Train Loss 0.1467 | Val Accuracy 0.6867
# Epoch 00049 | Time(s) 0.4193 | Train Loss 0.1654 | Val Accuracy 0.6900
# Epoch 00050 | Time(s) 0.4188 | Train Loss 0.1237 | Val Accuracy 0.7067
# Epoch 00051 | Time(s) 0.4205 | Train Loss 0.0810 | Val Accuracy 0.7067
# Epoch 00052 | Time(s) 0.4219 | Train Loss 0.1033 | Val Accuracy 0.7100
# Epoch 00053 | Time(s) 0.4196 | Train Loss 0.1464 | Val Accuracy 0.7100
# Epoch 00054 | Time(s) 0.4192 | Train Loss 0.0782 | Val Accuracy 0.7000
# Epoch 00055 | Time(s) 0.4170 | Train Loss 0.1227 | Val Accuracy 0.7033
# Epoch 00056 | Time(s) 0.4167 | Train Loss 0.0749 | Val Accuracy 0.7267
# Epoch 00057 | Time(s) 0.4147 | Train Loss 0.1436 | Val Accuracy 0.7267
# Epoch 00058 | Time(s) 0.4128 | Train Loss 0.1195 | Val Accuracy 0.7233
# Epoch 00059 | Time(s) 0.4160 | Train Loss 0.1471 | Val Accuracy 0.7333
# Epoch 00060 | Time(s) 0.4173 | Train Loss 0.2463 | Val Accuracy 0.7433
# Epoch 00061 | Time(s) 0.4154 | Train Loss 0.0867 | Val Accuracy 0.7467
# Epoch 00062 | Time(s) 0.4152 | Train Loss 0.1045 | Val Accuracy 0.7433
# Epoch 00063 | Time(s) 0.4167 | Train Loss 0.0918 | Val Accuracy 0.7400
# Epoch 00064 | Time(s) 0.4163 | Train Loss 0.1339 | Val Accuracy 0.7467
# Epoch 00065 | Time(s) 0.4162 | Train Loss 0.1264 | Val Accuracy 0.7433
# Epoch 00066 | Time(s) 0.4159 | Train Loss 0.0748 | Val Accuracy 0.7267
# Epoch 00067 | Time(s) 0.4157 | Train Loss 0.0651 | Val Accuracy 0.7300
# Epoch 00068 | Time(s) 0.4170 | Train Loss 0.1006 | Val Accuracy 0.7333
# Epoch 00069 | Time(s) 0.4183 | Train Loss 0.0609 | Val Accuracy 0.7433
# Epoch 00070 | Time(s) 0.4196 | Train Loss 0.1295 | Val Accuracy 0.7600
# Epoch 00071 | Time(s) 0.4193 | Train Loss 0.1142 | Val Accuracy 0.7700
# Epoch 00072 | Time(s) 0.4233 | Train Loss 0.1545 | Val Accuracy 0.7700
# Epoch 00073 | Time(s) 0.4232 | Train Loss 0.1416 | Val Accuracy 0.7600
# Epoch 00074 | Time(s) 0.4268 | Train Loss 0.1315 | Val Accuracy 0.7667
# Epoch 00075 | Time(s) 0.4304 | Train Loss 0.1336 | Val Accuracy 0.7733
# Epoch 00076 | Time(s) 0.4339 | Train Loss 0.1562 | Val Accuracy 0.7867
# Epoch 00077 | Time(s) 0.4361 | Train Loss 0.0891 | Val Accuracy 0.7967
# Epoch 00078 | Time(s) 0.4356 | Train Loss 0.1586 | Val Accuracy 0.7867
# Epoch 00079 | Time(s) 0.4377 | Train Loss 0.0696 | Val Accuracy 0.7833
# Epoch 00080 | Time(s) 0.4382 | Train Loss 0.0773 | Val Accuracy 0.7833
# Epoch 00081 | Time(s) 0.4405 | Train Loss 0.0517 | Val Accuracy 0.8067
# Epoch 00082 | Time(s) 0.4412 | Train Loss 0.0549 | Val Accuracy 0.8133
# Epoch 00083 | Time(s) 0.4420 | Train Loss 0.0961 | Val Accuracy 0.7933
# Epoch 00084 | Time(s) 0.4452 | Train Loss 0.0684 | Val Accuracy 0.7933
# Epoch 00085 | Time(s) 0.4458 | Train Loss 0.1398 | Val Accuracy 0.7967
# Epoch 00086 | Time(s) 0.4475 | Train Loss 0.0470 | Val Accuracy 0.8067
# Epoch 00087 | Time(s) 0.4481 | Train Loss 0.1461 | Val Accuracy 0.8067
# Epoch 00088 | Time(s) 0.4475 | Train Loss 0.1203 | Val Accuracy 0.8033
# Epoch 00089 | Time(s) 0.4471 | Train Loss 0.0891 | Val Accuracy 0.7967
# Epoch 00090 | Time(s) 0.4476 | Train Loss 0.1173 | Val Accuracy 0.7967
# Epoch 00091 | Time(s) 0.4460 | Train Loss 0.2160 | Val Accuracy 0.8067
# Epoch 00092 | Time(s) 0.4457 | Train Loss 0.0721 | Val Accuracy 0.8033
# Epoch 00093 | Time(s) 0.4451 | Train Loss 0.1181 | Val Accuracy 0.7900
# Epoch 00094 | Time(s) 0.4436 | Train Loss 0.0720 | Val Accuracy 0.7833
# Epoch 00095 | Time(s) 0.4431 | Train Loss 0.0710 | Val Accuracy 0.7900
# Epoch 00096 | Time(s) 0.4416 | Train Loss 0.1070 | Val Accuracy 0.7867
# Epoch 00097 | Time(s) 0.4412 | Train Loss 0.1743 | Val Accuracy 0.7933
# Epoch 00098 | Time(s) 0.4395 | Train Loss 0.0780 | Val Accuracy 0.7867
# Epoch 00099 | Time(s) 0.4400 | Train Loss 0.1225 | Val Accuracy 0.7900
# Epoch 00100 | Time(s) 0.4416 | Train Loss 0.1259 | Val Accuracy 0.7933
# Epoch 00101 | Time(s) 0.4412 | Train Loss 0.1235 | Val Accuracy 0.7867
# Epoch 00102 | Time(s) 0.4418 | Train Loss 0.1146 | Val Accuracy 0.7933
# Epoch 00103 | Time(s) 0.4404 | Train Loss 0.0700 | Val Accuracy 0.7933
# Epoch 00104 | Time(s) 0.4400 | Train Loss 0.0880 | Val Accuracy 0.7967
# Epoch 00105 | Time(s) 0.4396 | Train Loss 0.1469 | Val Accuracy 0.8033
# Epoch 00106 | Time(s) 0.4401 | Train Loss 0.1266 | Val Accuracy 0.7967
# Epoch 00107 | Time(s) 0.4416 | Train Loss 0.0842 | Val Accuracy 0.8000
# Epoch 00108 | Time(s) 0.4412 | Train Loss 0.1460 | Val Accuracy 0.8100
# Epoch 00109 | Time(s) 0.4417 | Train Loss 0.0910 | Val Accuracy 0.8067
# Epoch 00110 | Time(s) 0.4413 | Train Loss 0.0977 | Val Accuracy 0.8000
# Epoch 00111 | Time(s) 0.4401 | Train Loss 0.1613 | Val Accuracy 0.7933
# Epoch 00112 | Time(s) 0.4397 | Train Loss 0.1181 | Val Accuracy 0.7933
# Epoch 00113 | Time(s) 0.4394 | Train Loss 0.0831 | Val Accuracy 0.7967
# Epoch 00114 | Time(s) 0.4390 | Train Loss 0.1270 | Val Accuracy 0.8067
# Epoch 00115 | Time(s) 0.4382 | Train Loss 0.1336 | Val Accuracy 0.8067
# Epoch 00116 | Time(s) 0.4378 | Train Loss 0.1519 | Val Accuracy 0.8100
# Epoch 00117 | Time(s) 0.4377 | Train Loss 0.1130 | Val Accuracy 0.8133
# Epoch 00118 | Time(s) 0.4382 | Train Loss 0.1159 | Val Accuracy 0.8067
# Epoch 00119 | Time(s) 0.4404 | Train Loss 0.0751 | Val Accuracy 0.8000
# Epoch 00120 | Time(s) 0.4408 | Train Loss 0.1085 | Val Accuracy 0.7867
# Epoch 00121 | Time(s) 0.4405 | Train Loss 0.1055 | Val Accuracy 0.7833
# Epoch 00122 | Time(s) 0.4394 | Train Loss 0.1039 | Val Accuracy 0.7967
# Epoch 00123 | Time(s) 0.4407 | Train Loss 0.0632 | Val Accuracy 0.7967
# Epoch 00124 | Time(s) 0.4404 | Train Loss 0.0797 | Val Accuracy 0.8067
# Epoch 00125 | Time(s) 0.4408 | Train Loss 0.1078 | Val Accuracy 0.8200
# Epoch 00126 | Time(s) 0.4405 | Train Loss 0.0771 | Val Accuracy 0.8200
# Epoch 00127 | Time(s) 0.4426 | Train Loss 0.1141 | Val Accuracy 0.8267
# Epoch 00128 | Time(s) 0.4423 | Train Loss 0.0711 | Val Accuracy 0.8167
# Epoch 00129 | Time(s) 0.4429 | Train Loss 0.0351 | Val Accuracy 0.8067
# Epoch 00130 | Time(s) 0.4441 | Train Loss 0.0616 | Val Accuracy 0.8067
# Epoch 00131 | Time(s) 0.4437 | Train Loss 0.0341 | Val Accuracy 0.8033
# Epoch 00132 | Time(s) 0.4448 | Train Loss 0.1633 | Val Accuracy 0.8000
# Epoch 00133 | Time(s) 0.4445 | Train Loss 0.0640 | Val Accuracy 0.8067
# Epoch 00134 | Time(s) 0.4442 | Train Loss 0.1462 | Val Accuracy 0.7933
# Epoch 00135 | Time(s) 0.4439 | Train Loss 0.1688 | Val Accuracy 0.7967
# Epoch 00136 | Time(s) 0.4442 | Train Loss 0.0565 | Val Accuracy 0.7900
# Epoch 00137 | Time(s) 0.4446 | Train Loss 0.1007 | Val Accuracy 0.7933
# Epoch 00138 | Time(s) 0.4449 | Train Loss 0.1076 | Val Accuracy 0.7900
# Epoch 00139 | Time(s) 0.4468 | Train Loss 0.0934 | Val Accuracy 0.7800
# Epoch 00140 | Time(s) 0.4472 | Train Loss 0.1512 | Val Accuracy 0.7833
# Epoch 00141 | Time(s) 0.4462 | Train Loss 0.1933 | Val Accuracy 0.7933
# Epoch 00142 | Time(s) 0.4465 | Train Loss 0.0495 | Val Accuracy 0.8067
# Epoch 00143 | Time(s) 0.4461 | Train Loss 0.1282 | Val Accuracy 0.8233
# Epoch 00144 | Time(s) 0.4452 | Train Loss 0.0647 | Val Accuracy 0.8100
# Epoch 00145 | Time(s) 0.4449 | Train Loss 0.0967 | Val Accuracy 0.7833
# Epoch 00146 | Time(s) 0.4460 | Train Loss 0.1638 | Val Accuracy 0.7733
# Epoch 00147 | Time(s) 0.4450 | Train Loss 0.1062 | Val Accuracy 0.7600
# Epoch 00148 | Time(s) 0.4454 | Train Loss 0.1045 | Val Accuracy 0.7833
# Epoch 00149 | Time(s) 0.4458 | Train Loss 0.0794 | Val Accuracy 0.7767
# Epoch 00150 | Time(s) 0.4455 | Train Loss 0.1241 | Val Accuracy 0.7700
# Epoch 00151 | Time(s) 0.4439 | Train Loss 0.1156 | Val Accuracy 0.7900
# Epoch 00152 | Time(s) 0.4434 | Train Loss 0.1281 | Val Accuracy 0.7933
# Epoch 00153 | Time(s) 0.4431 | Train Loss 0.1119 | Val Accuracy 0.7933
# Epoch 00154 | Time(s) 0.4426 | Train Loss 0.1068 | Val Accuracy 0.7933
# Epoch 00155 | Time(s) 0.4432 | Train Loss 0.1441 | Val Accuracy 0.7900
# Epoch 00156 | Time(s) 0.4432 | Train Loss 0.2421 | Val Accuracy 0.7900
# Epoch 00157 | Time(s) 0.4448 | Train Loss 0.1506 | Val Accuracy 0.7900
# Epoch 00158 | Time(s) 0.4459 | Train Loss 0.1215 | Val Accuracy 0.7967
# Epoch 00159 | Time(s) 0.4474 | Train Loss 0.0606 | Val Accuracy 0.7933
# Epoch 00160 | Time(s) 0.4482 | Train Loss 0.0951 | Val Accuracy 0.7800
# Epoch 00161 | Time(s) 0.4485 | Train Loss 0.0957 | Val Accuracy 0.7800
# Epoch 00162 | Time(s) 0.4495 | Train Loss 0.1215 | Val Accuracy 0.7767
# Epoch 00163 | Time(s) 0.4503 | Train Loss 0.0952 | Val Accuracy 0.7733
# Epoch 00164 | Time(s) 0.4501 | Train Loss 0.0784 | Val Accuracy 0.7733
# Epoch 00165 | Time(s) 0.4504 | Train Loss 0.0986 | Val Accuracy 0.7767
# Epoch 00166 | Time(s) 0.4507 | Train Loss 0.1031 | Val Accuracy 0.7733
# Epoch 00167 | Time(s) 0.4527 | Train Loss 0.0998 | Val Accuracy 0.7700
# Epoch 00168 | Time(s) 0.4536 | Train Loss 0.1155 | Val Accuracy 0.7667
# Epoch 00169 | Time(s) 0.4545 | Train Loss 0.0587 | Val Accuracy 0.7700
# Epoch 00170 | Time(s) 0.4554 | Train Loss 0.1053 | Val Accuracy 0.7733
# Epoch 00171 | Time(s) 0.4550 | Train Loss 0.1105 | Val Accuracy 0.7800
# Epoch 00172 | Time(s) 0.4565 | Train Loss 0.0644 | Val Accuracy 0.7800
# Epoch 00173 | Time(s) 0.4584 | Train Loss 0.1123 | Val Accuracy 0.7833
# Epoch 00174 | Time(s) 0.4581 | Train Loss 0.0914 | Val Accuracy 0.7833
# Epoch 00175 | Time(s) 0.4578 | Train Loss 0.1248 | Val Accuracy 0.7900
# Epoch 00176 | Time(s) 0.4575 | Train Loss 0.1027 | Val Accuracy 0.8033
# Epoch 00177 | Time(s) 0.4566 | Train Loss 0.1096 | Val Accuracy 0.8100
# Epoch 00178 | Time(s) 0.4563 | Train Loss 0.0876 | Val Accuracy 0.8033
# Epoch 00179 | Time(s) 0.4560 | Train Loss 0.0776 | Val Accuracy 0.8100
# Epoch 00180 | Time(s) 0.4559 | Train Loss 0.0808 | Val Accuracy 0.8033
# Epoch 00181 | Time(s) 0.4551 | Train Loss 0.1100 | Val Accuracy 0.8133
# Epoch 00182 | Time(s) 0.4563 | Train Loss 0.0791 | Val Accuracy 0.8200
# Epoch 00183 | Time(s) 0.4566 | Train Loss 0.0502 | Val Accuracy 0.8200
# Epoch 00184 | Time(s) 0.4563 | Train Loss 0.0948 | Val Accuracy 0.8133
# Epoch 00185 | Time(s) 0.4570 | Train Loss 0.1383 | Val Accuracy 0.8200
# Epoch 00186 | Time(s) 0.4578 | Train Loss 0.0934 | Val Accuracy 0.8033
# Epoch 00187 | Time(s) 0.4581 | Train Loss 0.0651 | Val Accuracy 0.7933
# Epoch 00188 | Time(s) 0.4577 | Train Loss 0.1130 | Val Accuracy 0.7700
# Epoch 00189 | Time(s) 0.4575 | Train Loss 0.0959 | Val Accuracy 0.7633
# Epoch 00190 | Time(s) 0.4575 | Train Loss 0.0956 | Val Accuracy 0.7700
# Epoch 00191 | Time(s) 0.4567 | Train Loss 0.0997 | Val Accuracy 0.7767
# Epoch 00192 | Time(s) 0.4569 | Train Loss 0.2162 | Val Accuracy 0.7833
# Epoch 00193 | Time(s) 0.4571 | Train Loss 0.1859 | Val Accuracy 0.7867
# Epoch 00194 | Time(s) 0.4568 | Train Loss 0.1277 | Val Accuracy 0.8067
# Epoch 00195 | Time(s) 0.4580 | Train Loss 0.1619 | Val Accuracy 0.8033
# Epoch 00196 | Time(s) 0.4588 | Train Loss 0.0840 | Val Accuracy 0.7867
# Epoch 00197 | Time(s) 0.4585 | Train Loss 0.1297 | Val Accuracy 0.7900
# Epoch 00198 | Time(s) 0.4572 | Train Loss 0.2419 | Val Accuracy 0.7933
# Epoch 00199 | Time(s) 0.4575 | Train Loss 0.1588 | Val Accuracy 0.8033
# Epoch 00200 | Time(s) 0.4576 | Train Loss 0.0771 | Val Accuracy 0.7933
# Epoch 00201 | Time(s) 0.4578 | Train Loss 0.1323 | Val Accuracy 0.7967
# Epoch 00202 | Time(s) 0.4580 | Train Loss 0.1501 | Val Accuracy 0.8033
# Epoch 00203 | Time(s) 0.4582 | Train Loss 0.1384 | Val Accuracy 0.8033
# Epoch 00204 | Time(s) 0.4584 | Train Loss 0.1227 | Val Accuracy 0.7833
# Epoch 00205 | Time(s) 0.4606 | Train Loss 0.1633 | Val Accuracy 0.7800
# Epoch 00206 | Time(s) 0.4627 | Train Loss 0.1255 | Val Accuracy 0.7833
# Epoch 00207 | Time(s) 0.4624 | Train Loss 0.1121 | Val Accuracy 0.7767
# Epoch 00208 | Time(s) 0.4620 | Train Loss 0.1708 | Val Accuracy 0.7833
# Epoch 00209 | Time(s) 0.4617 | Train Loss 0.1128 | Val Accuracy 0.7833
# Epoch 00210 | Time(s) 0.4614 | Train Loss 0.0888 | Val Accuracy 0.7967
# Epoch 00211 | Time(s) 0.4607 | Train Loss 0.1273 | Val Accuracy 0.7900
# Epoch 00212 | Time(s) 0.4604 | Train Loss 0.1115 | Val Accuracy 0.7967
# Epoch 00213 | Time(s) 0.4610 | Train Loss 0.0817 | Val Accuracy 0.7900
# Epoch 00214 | Time(s) 0.4607 | Train Loss 0.0959 | Val Accuracy 0.7900
# Epoch 00215 | Time(s) 0.4604 | Train Loss 0.1441 | Val Accuracy 0.7867
# Epoch 00216 | Time(s) 0.4597 | Train Loss 0.1649 | Val Accuracy 0.7867
# Epoch 00217 | Time(s) 0.4594 | Train Loss 0.1452 | Val Accuracy 0.7967
# Epoch 00218 | Time(s) 0.4587 | Train Loss 0.0684 | Val Accuracy 0.8100
# Epoch 00219 | Time(s) 0.4580 | Train Loss 0.0722 | Val Accuracy 0.8033
# Epoch 00220 | Time(s) 0.4577 | Train Loss 0.0902 | Val Accuracy 0.8067
# Epoch 00221 | Time(s) 0.4570 | Train Loss 0.0941 | Val Accuracy 0.7967
# Epoch 00222 | Time(s) 0.4569 | Train Loss 0.0890 | Val Accuracy 0.8000
# Epoch 00223 | Time(s) 0.4566 | Train Loss 0.0861 | Val Accuracy 0.7967
# Epoch 00224 | Time(s) 0.4559 | Train Loss 0.0745 | Val Accuracy 0.7933
# Epoch 00225 | Time(s) 0.4562 | Train Loss 0.1069 | Val Accuracy 0.8000
# Epoch 00226 | Time(s) 0.4551 | Train Loss 0.1434 | Val Accuracy 0.7867
# Epoch 00227 | Time(s) 0.4548 | Train Loss 0.0781 | Val Accuracy 0.7867
# Epoch 00228 | Time(s) 0.4545 | Train Loss 0.1266 | Val Accuracy 0.7933
# Epoch 00229 | Time(s) 0.4542 | Train Loss 0.1317 | Val Accuracy 0.7900
# Epoch 00230 | Time(s) 0.4536 | Train Loss 0.0926 | Val Accuracy 0.7900
# Epoch 00231 | Time(s) 0.4537 | Train Loss 0.1369 | Val Accuracy 0.7967
# Epoch 00232 | Time(s) 0.4535 | Train Loss 0.1245 | Val Accuracy 0.8000
# Epoch 00233 | Time(s) 0.4529 | Train Loss 0.1000 | Val Accuracy 0.8133
# Epoch 00234 | Time(s) 0.4530 | Train Loss 0.1548 | Val Accuracy 0.8200
# Epoch 00235 | Time(s) 0.4528 | Train Loss 0.1935 | Val Accuracy 0.8200
# Epoch 00236 | Time(s) 0.4535 | Train Loss 0.0774 | Val Accuracy 0.8233
# Epoch 00237 | Time(s) 0.4533 | Train Loss 0.1388 | Val Accuracy 0.8233
# Epoch 00238 | Time(s) 0.4530 | Train Loss 0.0648 | Val Accuracy 0.8267
# Epoch 00239 | Time(s) 0.4528 | Train Loss 0.0978 | Val Accuracy 0.8133
# Epoch 00240 | Time(s) 0.4526 | Train Loss 0.0381 | Val Accuracy 0.8067
# Epoch 00241 | Time(s) 0.4528 | Train Loss 0.1424 | Val Accuracy 0.8000
# Epoch 00242 | Time(s) 0.4530 | Train Loss 0.0719 | Val Accuracy 0.8033
# Epoch 00243 | Time(s) 0.4527 | Train Loss 0.1215 | Val Accuracy 0.8033
# Epoch 00244 | Time(s) 0.4538 | Train Loss 0.2069 | Val Accuracy 0.7967
# Epoch 00245 | Time(s) 0.4544 | Train Loss 0.1318 | Val Accuracy 0.8000
# Epoch 00246 | Time(s) 0.4561 | Train Loss 0.0712 | Val Accuracy 0.8033
# Epoch 00247 | Time(s) 0.4559 | Train Loss 0.0678 | Val Accuracy 0.7933
# Epoch 00248 | Time(s) 0.4561 | Train Loss 0.1389 | Val Accuracy 0.7933
# Epoch 00249 | Time(s) 0.4563 | Train Loss 0.0561 | Val Accuracy 0.7867
# Epoch 00250 | Time(s) 0.4561 | Train Loss 0.1963 | Val Accuracy 0.7967
# Epoch 00251 | Time(s) 0.4563 | Train Loss 0.1730 | Val Accuracy 0.7933
# Epoch 00252 | Time(s) 0.4561 | Train Loss 0.1094 | Val Accuracy 0.7933
# Epoch 00253 | Time(s) 0.4554 | Train Loss 0.0818 | Val Accuracy 0.7967
# Epoch 00254 | Time(s) 0.4552 | Train Loss 0.1187 | Val Accuracy 0.8033
# Epoch 00255 | Time(s) 0.4549 | Train Loss 0.0792 | Val Accuracy 0.8167
# Epoch 00256 | Time(s) 0.4547 | Train Loss 0.1155 | Val Accuracy 0.8267
# Epoch 00257 | Time(s) 0.4548 | Train Loss 0.1258 | Val Accuracy 0.8267
# Epoch 00258 | Time(s) 0.4546 | Train Loss 0.0688 | Val Accuracy 0.8267
# Epoch 00259 | Time(s) 0.4540 | Train Loss 0.0820 | Val Accuracy 0.8200
# Epoch 00260 | Time(s) 0.4539 | Train Loss 0.1206 | Val Accuracy 0.8100
# Epoch 00261 | Time(s) 0.4537 | Train Loss 0.0876 | Val Accuracy 0.8067
# Epoch 00262 | Time(s) 0.4539 | Train Loss 0.0960 | Val Accuracy 0.8133
# Epoch 00263 | Time(s) 0.4545 | Train Loss 0.2272 | Val Accuracy 0.8233
# Epoch 00264 | Time(s) 0.4539 | Train Loss 0.0813 | Val Accuracy 0.8300
#
# Test Accuracy 0.7810

# %% [markdown]
# Trained this way our GCN based on polynomials of the laplacian is a black box. Fortunately, however, the only difference between this shallow model and our previous classifier is the way we chose the filter coefficients.
#
# Let's see what the network learned.
# Print the coefficients of the learned filter.

# %%
coeff_gcn =  model.pol_weights.data.numpy()# Your code here
print(coeff_gcn)
# Out:
# [ 5.582205  -7.1840887  2.468154 ]

# %% [markdown]
# To interpret the model we can plot the frequency response of the learned filter.

# %%
plt.semilogy(lam, np.abs(polynomial_graph_filter_response(coeff_gcn, lam)))
plt.xlabel('$\lambda$')
plt.ylabel('Spectral response (db)')
# Out:
# Text(0, 0.5, 'Spectral response (db)')

# %% [markdown]
# #### Question 19
#
# As we said, the whole classification pipeline of the previous exercise is identical to the one we tried before: Graph filtering + Logistic regression. The only difference lies in the way we chose the filter coefficients. First we were choosing them manually, and now, we let `PyTorch` find them for us. However, if everything is correct we should be able to use this filter to construct new hand-crafted features and train a logistic regression model that achieves good accuracy on the training set. Let's do that!

# %% [markdown]
# Use the learned coefficients to train a new feature extractor:

# %%
graph_gcn_filter = polynomial_graph_filter(coeff_gcn, laplacian) # Your code here

# %% [markdown]
# Let's extract the new features by filtering the data:

# %%
features_gcn = graph_gcn_filter @ features.numpy()

train_features_gcn = features_gcn[train_mask,:]
train_labels = labels[train_mask]
val_features_gcn = features_gcn[val_mask,:]
val_labels = labels[val_mask]
test_features_gcn = features_gcn[test_mask,:]
test_labels = labels[test_mask]

# %% [markdown]
# Train a logistic regression on these features:

# %%
# Your code here
C_group =  np.linspace(0.1,30, num=30)
score_train = []
score_val = []
for c in C_group:
    clf =LogisticRegression(C=c,penalty='l2',solver='sag',multi_class='multinomial').fit(train_features_gcn,train_labels)
    score_train.append(clf.score(train_features_gcn,train_labels))
    score_val.append(clf.score(val_features_gcn,val_labels))
    print('C is ',c)
    print('train accuracy is :' ,score_train[-1])
    print('validate accuracy is :' ,score_val[-1])
    
C = C_group[np.argmax(score_val)]
clf =LogisticRegression(C=C,penalty='l2',solver='sag',multi_class='multinomial').fit(train_features_gcn,train_labels)
# Out:
# C is  0.1
# train accuracy is : 0.30714285714285716
# validate accuracy is : 0.35
# C is  1.1310344827586207
# train accuracy is : 0.7214285714285714
# validate accuracy is : 0.6233333333333333
# C is  2.1620689655172414
# train accuracy is : 0.8571428571428571
# validate accuracy is : 0.7133333333333334
# C is  3.193103448275862
# train accuracy is : 0.9
# validate accuracy is : 0.7566666666666667
# C is  4.224137931034482
# train accuracy is : 0.9285714285714286
# validate accuracy is : 0.7733333333333333
# C is  5.255172413793103
# train accuracy is : 0.95
# validate accuracy is : 0.7833333333333333
# C is  6.2862068965517235
# train accuracy is : 0.9642857142857143
# validate accuracy is : 0.7866666666666666
# C is  7.317241379310344
# train accuracy is : 0.9642857142857143
# validate accuracy is : 0.7866666666666666
# C is  8.348275862068965
# train accuracy is : 0.9714285714285714
# validate accuracy is : 0.79
# C is  9.379310344827585
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.7933333333333333
# C is  10.410344827586206
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.7933333333333333
# C is  11.441379310344827
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.7966666666666666
# C is  12.472413793103447
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.7933333333333333
# C is  13.503448275862068
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.7966666666666666
# C is  14.534482758620689
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.7966666666666666
# C is  15.56551724137931
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.8
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  16.59655172413793
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.8
# C is  17.627586206896552
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  18.658620689655173
# train accuracy is : 0.9857142857142858
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  19.689655172413794
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  20.720689655172414
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  21.751724137931035
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  22.782758620689656
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  23.813793103448276
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  24.844827586206897
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.7966666666666666
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  25.875862068965517
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  26.906896551724138
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8066666666666666
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  27.93793103448276
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  28.96896551724138
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C is  30.0
# train accuracy is : 0.9928571428571429
# validate accuracy is : 0.8033333333333333
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %% [markdown]
# Finally, let's evaluate this model:

# %%
train_acc =clf.score(train_features_gcn, train_labels)  # Your code here
val_acc = clf.score(val_features_gcn, val_labels) # Your code here
test_acc = clf.score(test_features_gcn, test_labels) # Your code here

print('Train accuracy {:.4f} | Validation accuracy {:.4f} | Test accuracy {:.4f}'.format(train_acc, val_acc, test_acc))
# Out:
# Train accuracy 0.9929 | Validation accuracy 0.8033 | Test accuracy 0.8130

# %% [markdown]
# The performance of this model may not be exactly the same as the one obtained with Pytorch. What are the differences in the training procedure that can explain this gap?

# %% [markdown]
# *Your answer here*

# %% [markdown]
# since the weights of two LogisticRegression models are different and also the methods to compute the optimization are different
